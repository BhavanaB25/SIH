# %% [markdown]
# <a href="https://colab.research.google.com/github/BhavanaB25/SIH/blob/main/BhavanaDTI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

# Define paths
zip_path = "/content/drive/MyDrive/MyProject/DTI/dti.zip"
csv_path = "/content/drive/MyDrive/MyProject/DTI/DTI_CSV.csv"
extract_path = "/content/drive/MyDrive/MyProject/DTI/dti_extracted"

# Check if files exist
if os.path.exists(zip_path):
    print("✅ Found dti.zip")
else:
    print("❌ dti.zip not found! Check the path.")

if os.path.exists(csv_path):
    print("✅ Found DTI_CSV.csv")
else:
    print("❌ DTI_CSV.csv not found! Check the path.")
# Out:
# ✅ Found dti.zip
# ✅ Found DTI_CSV.csv

# %%
# List extracted files
extracted_files = os.listdir(extract_path)

# Show first 10 extracted folders
print("Extracted Patient Folders:", extracted_files[:10])
# Out:
# Extracted Patient Folders: ['ADNI']

# %%
import pandas as pd

# Load the CSV
df = pd.read_csv(csv_path)

# Display first few rows
print("CSV Columns:", df.columns)
print(df.head(10))  # Show first 10 rows
# Out:
# CSV Columns: Index(['Subject_ID', 'Diagnosis', 'Image_UID'], dtype='object')
#    Subject_ID Diagnosis  Image_UID
# 0  003_S_0908       MCI     404525
# 1  003_S_1074       MCI     487988
# 2  003_S_2374       MCI     234455
# 3  003_S_2374       MCI     502312
# 4  003_S_4081        CN     244118
# 5  003_S_4081        CN     391275
# 6  003_S_4119        CN     250888
# 7  003_S_4119        CN     287304
# 8  003_S_4119        CN     333869
# 9  003_S_4119        CN     384078

# %%
import pandas as pd
import os

# Define paths
csv_path = "/content/drive/MyDrive/MyProject/DTI/DTI_CSV.csv"
extracted_root = "/content/drive/MyDrive/MyProject/DTI/dti_extracted"

# Load CSV file
df = pd.read_csv(csv_path)
csv_patient_ids = set(df["Subject_ID"].astype(str).str.strip().str.upper())

# Get extracted patient folder names
extracted_patient_ids = set(os.listdir(extracted_root))

# Find matches and mismatches
matching_patients = csv_patient_ids & extracted_patient_ids
missing_in_extracted = csv_patient_ids - extracted_patient_ids
extra_in_extracted = extracted_patient_ids - csv_patient_ids

# Print summary
print(f"✅ Matching Patients: {len(matching_patients)}")
print(f"❌ Patients in CSV but not extracted: {len(missing_in_extracted)}")
print(f"⚠️ Patients extracted but not in CSV: {len(extra_in_extracted)}")

# Display some mismatches
print(f"❌ Missing in Extracted (first 10): {list(missing_in_extracted)[:10]}")
print(f"⚠️ Extra in Extracted (first 10): {list(extra_in_extracted)[:10]}")
# Out:
# ✅ Matching Patients: 0
# ❌ Patients in CSV but not extracted: 249
# ⚠️ Patients extracted but not in CSV: 1
# ❌ Missing in Extracted (first 10): ['021_S_4857', '027_S_4943', '029_S_4290', '127_S_5095', '129_S_4371', '003_S_5165', '027_S_4966', '029_S_5135', '094_S_4649', '098_S_4059']
# ⚠️ Extra in Extracted (first 10): ['ADNI']

# %%
import os
import shutil

# Define category folders
output_dir = "/content/drive/MyDrive/MyProject/DTI_Categorized"
categories = ["AD", "CN", "MCI"]

# Create category folders if they don’t exist
for category in categories:
    os.makedirs(os.path.join(output_dir, category), exist_ok=True)

# Move patients to respective folders
for _, row in df.iterrows():
    patient_id = str(row["Subject_ID"]).strip().upper()
    category = row["Diagnosis"].strip().upper()

    src_path = os.path.join(extracted_root, patient_id)
    dest_path = os.path.join(output_dir, category, patient_id)

    if os.path.exists(src_path):
        shutil.move(src_path, dest_path)

print("✅ All patients have been categorized successfully!")
# Out:
# ✅ All patients have been categorized successfully!

# %%
for category in categories:
    folder_path = os.path.join(output_dir, category)
    print(f"📂 {category}: {len(os.listdir(folder_path))} patients")
# Out:
# 📂 AD: 49 patients
# 📂 CN: 69 patients
# 📂 MCI: 131 patients

# %%
# Patients from CSV
csv_patients_by_category = {category: set(df[df["Diagnosis"] == category]["Subject_ID"].astype(str)) for category in categories}

# Patients in categorized folders
categorized_patients_by_folder = {category: set(os.listdir(os.path.join(output_dir, category))) for category in categories}

# Find mismatches
for category in categories:
    missing = csv_patients_by_category[category] - categorized_patients_by_folder[category]
    extra = categorized_patients_by_folder[category] - csv_patients_by_category[category]

    print(f"🔍 {category} - Missing in Categorized: {len(missing)} | Extra in Categorized: {len(extra)}")
# Out:
# 🔍 AD - Missing in Categorized: 49 | Extra in Categorized: 0
# 🔍 CN - Missing in Categorized: 69 | Extra in Categorized: 0
# 🔍 MCI - Missing in Categorized: 131 | Extra in Categorized: 0

# %%
# !pip install nibabel dipy nilearn dicom2nifti antspyx
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.8/8.8 MB 79.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.5/10.5 MB 119.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 kB 3.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 22.2/22.2 MB 76.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 67.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.2/45.2 kB 3.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.1/13.1 MB 92.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.2/86.2 kB 8.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.9/43.9 kB 3.5 MB/s eta 0:00:00
# ...

# %%
import os

# Check extracted folders
extract_path = "/content/drive/MyDrive/MyProject/DTI/DTI_Categorized"

if os.path.exists(extract_path):
    print(f"✅ Extracted Folder Found: {extract_path}")
    print("📂 Contents:", os.listdir(extract_path))
else:
    print(f"❌ Extraction Failed! The folder '{extract_path}' does not exist.")
# Out:
# ✅ Extracted Folder Found: /content/drive/MyDrive/MyProject/DTI/DTI_Categorized
# 📂 Contents: ['ADNI']

# %%
import os
import shutil

# Paths
base_path = "/content/drive/MyDrive/MyProject/DTI/DTI_Categorized"
adni_path = os.path.join(base_path, "ADNI")

# Check if 'ADNI' folder exists
if os.path.exists(adni_path):
    # Move all patient folders out of 'ADNI'
    for patient_folder in os.listdir(adni_path):
        shutil.move(os.path.join(adni_path, patient_folder), base_path)

    # Remove the empty 'ADNI' folder
    shutil.rmtree(adni_path)
    print("✅ Fixed: Moved patient folders out of 'ADNI'.")

# Verify
patient_folders = os.listdir(base_path)
print(f"✅ Final Patient Count: {len(patient_folders)}")
print("📂 Example Patients:", patient_folders[:10])
# Out:
# ✅ Fixed: Moved patient folders out of 'ADNI'.
# ✅ Final Patient Count: 13
# 📂 Example Patients: ['016_S_2031', '098_S_2047', '016_S_2007', '007_S_2058', '098_S_2071', '098_S_2052', '021_S_2077', '098_S_2079', '007_S_2106', '021_S_2100']

# %%
import os

base_path = "/content/drive/MyDrive/MyProject/DTI/DTI_Categorized"

# List extracted folders
patient_folders = os.listdir(base_path)
print(f"✅ Final Patient Count: {len(patient_folders)}")
print("📂 Example Patients:", patient_folders[:10])
# Out:
# ✅ Final Patient Count: 13
# 📂 Example Patients: ['016_S_2031', '098_S_2047', '016_S_2007', '007_S_2058', '098_S_2071', '098_S_2052', '021_S_2077', '098_S_2079', '007_S_2106', '021_S_2100']

# %%
import os
import shutil
import pandas as pd

# Paths
base_path = "/content/drive/MyDrive/MyProject/DTI/DTI_Categorized"
csv_path = "/content/drive/MyDrive/MyProject/DTI/DTI_CSV.csv"

# Load CSV
df = pd.read_csv(csv_path)

# Ensure the necessary category folders exist
categories = ["AD", "CN", "MCI"]
for category in categories:
    os.makedirs(os.path.join(base_path, category), exist_ok=True)

# Move patients to respective category folders
moved_count = 0
not_found = []

for _, row in df.iterrows():
    patient_id = row["Subject_ID"]
    category = row["Diagnosis"]

    patient_folder = os.path.join(base_path, patient_id)
    target_folder = os.path.join(base_path, category)

    if os.path.exists(patient_folder):
        shutil.move(patient_folder, target_folder)
        moved_count += 1
    else:
        not_found.append(patient_id)

# Results
print(f"✅ Successfully Moved {moved_count} Patients to AD, CN, and MCI Folders")
print(f"❌ Not Found Patients: {len(not_found)}")
if not_found:
    print("🚨 First 10 Missing Patients:", not_found[:10])
# Out:
# ✅ Successfully Moved 13 Patients to AD, CN, and MCI Folders
# ❌ Not Found Patients: 926
# 🚨 First 10 Missing Patients: ['003_S_0908', '003_S_1074', '003_S_2374', '003_S_2374', '003_S_4081', '003_S_4081', '003_S_4119', '003_S_4119', '003_S_4119', '003_S_4119']

# %%
dti_base = "/content/drive/MyDrive/MyProject/DTI"
print("📂 Contents of DTI:", os.listdir(dti_base))
# Out:
# 📂 Contents of DTI: ['dti.zip', 'DTI_CSV.csv', 'dti_extracted', 'DTI_Categorized']

# %%
import os
import nibabel as nib
import numpy as np
import cv2
import matplotlib.pyplot as plt

# Define input & output paths
base_path = "/content/drive/MyDrive/MyProject/DTI/DTI_Categorized"
output_path = "/content/drive/MyDrive/MyProject/DTI/DTI_Preprocessed"

# Ensure output directory exists
os.makedirs(output_path, exist_ok=True)

# Resize shape (modify based on your model requirements)
IMG_SIZE = (128, 128)

# Function to preprocess DTI images
def preprocess_dti(input_folder, output_folder):
    """Preprocess DTI images: load, resize, normalize, and save."""
    for category in ["AD", "CN", "MCI"]:
        input_category_path = os.path.join(input_folder, category)
        output_category_path = os.path.join(output_folder, category)
        os.makedirs(output_category_path, exist_ok=True)

        for patient_id in os.listdir(input_category_path):
            patient_folder = os.path.join(input_category_path, patient_id)

            # Check if the patient folder exists
            if not os.path.isdir(patient_folder):
                continue

            for file in os.listdir(patient_folder):
                if file.endswith(".nii") or file.endswith(".nii.gz"):  # Check if it's a NIfTI file
                    file_path = os.path.join(patient_folder, file)

                    try:
                        # Load NIfTI image
                        img = nib.load(file_path).get_fdata()

                        # Normalize image (0 to 1 range)
                        img = (img - np.min(img)) / (np.max(img) - np.min(img) + 1e-8)

                        # Resize slices
                        resized_slices = []
                        for i in range(img.shape[2]):  # Iterate over slices
                            slice_resized = cv2.resize(img[:, :, i], IMG_SIZE, interpolation=cv2.INTER_AREA)
                            resized_slices.append(slice_resized)

                        resized_slices = np.array(resized_slices)

                        # Save preprocessed image as .npy file
                        output_file = os.path.join(output_category_path, f"{patient_id}.npy")
                        np.save(output_file, resized_slices)

                        print(f"✅ Processed: {file_path} → {output_file}")

                    except Exception as e:
                        print(f"❌ Error processing {file_path}: {e}")

# Run preprocessing
preprocess_dti(base_path, output_path)
print("\n🎉 Preprocessing Complete! Preprocessed data saved in:", output_path)
# Out:
# 🎉 Preprocessing Complete! Preprocessed data saved in: /content/drive/MyDrive/MyProject/DTI/DTI_Preprocessed

# %% [markdown]
# CNN Model (ResNet-3D, DenseNet-3D, and EfficientNet-3D in PyTorch)

# %%
# !pip install torch torchvision monai timm
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 43.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 43.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 37.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 14.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 7.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 32.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 46.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import models
from monai.networks.nets import resnet, densenet, efficientnet

# %%
from monai.networks.nets import EfficientNetBN

class DTI_Classifier(nn.Module):
    def __init__(self, num_classes=3):
        super(DTI_Classifier, self).__init__()

        # Load pre-trained 3D CNN models
        self.resnet3d = resnet.resnet50(spatial_dims=3, n_input_channels=1, num_classes=num_classes)
        self.densenet3d = densenet.densenet121(spatial_dims=3, in_channels=1, out_channels=num_classes)
        self.efficientnet3d = EfficientNetBN(model_name="efficientnet-b0", in_channels=1, num_classes=num_classes)

        # Fully connected layer to combine features
        self.fc = nn.Linear(num_classes * 3, num_classes)

    def forward(self, x):
        res_out = self.resnet3d(x)
        dense_out = self.densenet3d(x)
        eff_out = self.efficientnet3d(x)

        # Concatenate features
        combined_features = torch.cat((res_out, dense_out, eff_out), dim=1)

        # Final classification
        out = self.fc(combined_features)
        return out

# Define model
model = DTI_Classifier(num_classes=3)
# Out:
# Downloading: "https://github.com/lukemelas/EfficientNet-PyTorch/releases/download/1.0/efficientnet-b0-355c32eb.pth" to /root/.cache/torch/hub/checkpoints/efficientnet-b0-355c32eb.pth
# 100%|██████████| 20.4M/20.4M [00:00<00:00, 147MB/s]

# %%
from monai.networks.nets import EfficientNetBN
import torch
import torch.nn as nn
from monai.networks.nets import resnet, densenet

class DTI_Classifier(nn.Module):
    def __init__(self, num_classes=3):
        super(DTI_Classifier, self).__init__()

        # 3D ResNet
        self.resnet3d = resnet.resnet50(spatial_dims=3, n_input_channels=1, num_classes=num_classes)

        # 3D DenseNet
        self.densenet3d = densenet.densenet121(spatial_dims=3, in_channels=1, out_channels=num_classes)

        # 3D EfficientNet
        self.efficientnet3d = EfficientNetBN(model_name="efficientnet-b0", in_channels=1, num_classes=num_classes)

        # Fully connected layer to combine outputs from all models
        self.fc = nn.Linear(num_classes * 3, num_classes)

    def forward(self, x):
        res_out = self.resnet3d(x)
        dense_out = self.densenet3d(x)
        eff_out = self.efficientnet3d(x)

        # Concatenating outputs from all networks
        combined_features = torch.cat((res_out, dense_out, eff_out), dim=1)

        # Final classification
        out = self.fc(combined_features)
        return out

# Define model
model = DTI_Classifier(num_classes=3)

# Print model summary
print(model)
# Out:
# DTI_Classifier(
#   (resnet3d): ResNet(
#     (conv1): Conv3d(1, 64, kernel_size=(7, 7, 7), stride=(1, 1, 1), padding=(3, 3, 3), bias=False)
#     (bn1): BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (act): ReLU(inplace=True)
#     (maxpool): MaxPool3d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (layer1): Sequential(
#       (0): ResNetBottleneck(
#         (conv1): Conv3d(64, 64, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (bn1): BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv3d(64, 64, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#         (bn2): BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv3d(64, 256, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (bn3): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# ...

# %%
# Define loss and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

# Move model to GPU if available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)
# Out:
# DTI_Classifier(
#   (resnet3d): ResNet(
#     (conv1): Conv3d(1, 64, kernel_size=(7, 7, 7), stride=(1, 1, 1), padding=(3, 3, 3), bias=False)
#     (bn1): BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (act): ReLU(inplace=True)
#     (maxpool): MaxPool3d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (layer1): Sequential(
#       (0): ResNetBottleneck(
#         (conv1): Conv3d(64, 64, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (bn1): BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv3d(64, 64, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#         (bn2): BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv3d(64, 256, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (bn3): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# ...

# %%
import torch
print(torch.cuda.is_available())  # Should print True
# Out:
# True

# %%
def evaluate_model(model, test_loader):
    model.eval()
    correct, total = 0, 0

    with torch.no_grad():
        for images, labels in test_loader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            _, predicted = torch.max(outputs, 1)
            correct += (predicted == labels).sum().item()
            total += labels.size(0)

    acc = correct / total
    print(f"Test Accuracy: {acc:.4f}")

# Call function
# evaluate_model(model, test_loader)
